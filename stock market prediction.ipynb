# %% [markdown]
# <a href="https://colab.research.google.com/github/nanditha-dotcom/stock-market-prediction-for-tesla-using-simple-linear-regression/blob/main/stock%20market%20prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# #importing dataset

# %%
df = pd.read_csv('TSLA.csv')
print(df.head())
df['Date'] = pd.to_datetime(df['Date'])
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %% [markdown]
# #creating target as close

# %%
features = df[['Open', 'High', 'Low']]
target = df['Close']

# %% [markdown]
# # Split Data into Training and Testing Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %% [markdown]
# # Create and train a Linear Regression model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Make predictions on the test data

# %%
predictions = model.predict(X_test)

# %% [markdown]
# # Visualize the results (actual vs. predicted stock prices)

# %%
plt.figure(figsize=(12, 6))
plt.title('Stock Price Prediction')
plt.plot(df['Date'][-len(y_test):], y_test, label='Actual Prices', color='red')
plt.plot(df['Date'][-len(y_test):], predictions, label='Predicted Prices', color='yellow')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 4.335994992006455
